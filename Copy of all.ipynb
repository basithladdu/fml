# %%
# 5 naive_bayes 

import pandas as pd 
import numpy as np 
from sklearn.metrics import classification_report, ConfusionMatrixDisplay,confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('iris_csv.csv')
df
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
x=df.drop('class',axis=1)
y=df['class']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
gg = GaussianNB()
gg.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred=gg.predict(x_test)

# %%
accuracy = accuracy_score(y_test,y_pred) * 100*1
accuracy
# Out:
# 100.0

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[10,  0,  0],
#        [ 0,  9,  0],
#        [ 0,  0, 11]])

# %%
matrix = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=gg.classes_)
matrix.plot()
plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00         9
#  Iris-virginica       1.00      1.00      1.00        11
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30

# %%
# 7 Implement Support Vector Machines on IRIS
import pandas as pd 
import numpy as np 
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris= load_iris()

# %%
x=iris.data
y=iris.target

# %%
 X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
model =SVC(kernel='rbf',C=1.0,gamma='scale')
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred=model.predict(X_test)

# %%
accuracy = accuracy_score(y_test,y_pred) * 100
accuracy
# Out:
# 100.0

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[19,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0, 13]])

# %%
matrix= ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model.classes_)
matrix.plot()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
# 4 Implement KNN Classifier

import pandas as pd 
import numpy as np 
from sklearn.metrics import classification_report
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay,confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score , f1_score ,recall_score,precision_score
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %%
df3=pd.read_csv('iris_csv.csv')
df
x = df3.drop(columns=['class']).values
y = df3['class'].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

model = KNeighborsClassifier()
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=model.predict(x_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
con=confusion_matrix(y_test,y_pred)
precision = precision_score(y_test, y_pred,average='macro')
recall = recall_score(y_test, y_pred,average='macro')
f1 = f1_score(y_test, y_pred,average='macro')
conf_matrix = confusion_matrix(y_test, y_pred)


print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", con)
print("Classification Report:\n", classification_report(y_test, y_pred))


plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Confusion Matrix:
#  [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
# Classification Report:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00         9
#  Iris-virginica       1.00      1.00      1.00        11
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30

# %%
# 6 liner 

import pandas as pd 
import numpy as np 
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score,mean_absolute_error,mean_squared_error,r2_score

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("linear.csv")
print(df)
x = df[['X']].values
y = df[['y']].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
# Out:
#         X           y
# 0     1.0   12.467142
# 1     2.0    8.617357
# 2     3.0   18.976885
# 3     4.0   30.230299
# 4     5.0   15.158466
# ..    ...         ...
# 95   96.0  230.364851
# 96   97.0  250.461203
# 97   98.0  252.610553
# 98   99.0  252.551135
# 99  100.0  252.654129
#
# [100 rows x 2 columns]

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("R-squared (R²):", r2)
# Out:
# Mean Squared Error (MSE): 62.20422422901786
# Mean Absolute Error (MAE): 6.01312347498312
# R-squared (R²): 0.9879803365658966

# %%
plt.scatter(x_test, y_test, color='blue', label='Actual')
plt.plot(x_test, y_pred, color='red', linewidth=2, label='Predicted')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Simple Linear Regression')
plt.legend()
plt.show()

# %%
# 8 tree

import pandas as pd 
import numpy as np 
from sklearn.tree import DecisionTreeClassifier , plot_tree
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
df3=pd.read_csv('sample.csv')
df3
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
le = LabelEncoder()
for col in df3.columns:
    df3[col] = le.fit_transform(df3[col])
x=df3.drop(columns=['Country'])
y=df3['Country']


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

model= DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(12, 6))
plot_tree(model, feature_names=x.columns, class_names=[str(cls) for cls in set(y)], filled=True)
plt.show()

# %%
y_pred = model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)*100
cm = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}\n')
print('Confusion Matrix:\n', cm)
print('\nClassification Report:\n', class_report)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
matrix = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model.classes_)
matrix.plot()
plt.show()

# %%
#9 ensemble

import pandas as pd 
import numpy as np 
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('linear.csv')
df=pd.DataFrame(df)

x=df.drop('y',axis=1)
y=df['y']

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.25, random_state=42)

# %%
model_1 = LinearRegression()
model_2 = RandomForestRegressor()
model_3 = SVR()

# %%
model_1.fit(x_train,y_train)
model_2.fit(x_train,y_train)
model_3.fit(x_train,y_train)
# Out:
# SVR()

# %%
y_predict1=model_1.predict(x_test)
y_predict2=model_2.predict(x_test)
y_predict3=model_3.predict(x_test)

# %%
pred_final = (y_predict1+y_predict2+y_predict3)/3.0

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, pred_final))
# Out:
# 351.88714522459077

# %%
# 10 Implement K Means Clustering algorithm


import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans 
from sklearn.metrics import silhouette_score

# %%
df=pd.read_csv('Clustering.csv')
x = df[["Age", "Annual_Income", "Spending_Score"]]

kmeans=KMeans(n_clusters=3,random_state=42)
df["cluster"]=kmeans.fit_predict(x)


iner = kmeans.inertia_
silhouette = silhouette_score(x,df["cluster"])

# %%
plt.figure(figsize=(8,6))
plt.scatter(df["Annual_Income"], df["Spending_Score"], c=df["cluster"], cmap='viridis', alpha=0.6)
plt.xlabel("Annual Income")  # Setting x-axis label
plt.ylabel("Spending Score")  # Setting y-axis label
plt.title("K-Means Clustering - Customer Segmentation")  # Setting plot title
plt.colorbar(label="Cluster")  # Adding color bar to indicate clusters
plt.show()  # Displaying the plot

# %%
print(f"Total Samples: {len(df)}")  
print(f"Cluster counts:\n{df['cluster'].value_counts()}") 
print(f"Inertia: {iner}") 
print(f"Silhouette Score: {silhouette}")
# Out:
# Total Samples: 198
# Cluster counts:
# cluster
# 0    69
# 1    66
# 2    63
# Name: count, dtype: int64
# Inertia: 4099384075.500267
# Silhouette Score: 0.7058744675703401

# %%
# 3 Build a digit image classifier on MNIST dataset


import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('mnist_train.csv')

# %%
nine = df.iloc[4, 1:]
nine.shape
# Out:
# (784,)

# %%
nine = nine.values.reshape(28, 28)
plt.imshow(nine, cmap='gray')

# %%
x=df.drop('label', axis=1)
y=df['label']
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.25, random_state=42)

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
model=SVC()
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_predict=knn.predict(x_test)
y_predict
# Out:
# array([7, 3, 8, ..., 7, 3, 0])

# %%
accuracy=accuracy_score(y_test,y_predict)*100
accuracy
# Out:
# 97.05333333333334

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_predict)
cm
# Out:
# array([[1481,    1,    1,    0,    1,    3,    5,    1,    1,    1],
#        [   0, 1640,    3,    0,    1,    0,    1,    3,    0,    1],
#        [  10,   13, 1414,    1,    3,    1,    2,   21,    4,    2],
#        [   2,    1,   12, 1466,    0,   16,    0,    8,    6,    7],
#        [   1,    7,    1,    1, 1397,    0,    2,    4,    1,   29],
#        [   9,    4,    1,   16,    2, 1328,   14,    0,    4,    5],
#        [   4,    4,    0,    0,    1,    4, 1469,    0,    0,    0],
#        [   0,   23,    5,    0,    3,    0,    0, 1596,    1,    7],
#        [   5,   15,   12,   22,   13,   20,    4,    2, 1344,    8],
#        [   4,    4,    2,    4,   20,    4,    2,   14,    2, 1423]])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

color = 'white'
matrix = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=model.classes_)
matrix.plot()

plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1495
#            1       0.96      0.99      0.98      1649
#            2       0.97      0.96      0.97      1471
#            3       0.97      0.97      0.97      1518
#            4       0.97      0.97      0.97      1443
#            5       0.97      0.96      0.96      1383
#            6       0.98      0.99      0.99      1482
#            7       0.97      0.98      0.97      1635
#            8       0.99      0.93      0.96      1445
#            9       0.96      0.96      0.96      1479
#
#     accuracy                           0.97     15000
#    macro avg       0.97      0.97      0.97     15000
# weighted avg       0.97      0.97      0.97     15000

# %%
#add2
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder,StandardScaler,OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

dataset = pd.read_csv('sample.csv')
dataset.head()
dataset.isnull().sum()
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:,3:].values

imp = SimpleImputer(missing_values = np.nan, strategy ='mean')
x[:,1:3] = imp.fit_transform(x[:,1:3])

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
x[:,0]=LE.fit_transform(x[:,0])
y=LE.fit_transform(y)

# %%
transform =  ColumnTransformer([("norm1",OneHotEncoder(),[0])], remainder = 'passthrough')
x = transform.fit_transform(x)

from sklearn.preprocessing import StandardScaler
SC = StandardScaler()
x_train[:,3:5]=SC.fit_transform(x_train[:,3:5])
print("Orignal Data:\n",dataset)
print("ML Needed a Data:\n")
x_trainx_train

# %%
# Implement data visualization techniques on public
import pandas as pd 
import numpy as np 

dataset = pd.read_csv('iris_csv.csv')
dataset.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
dataset.shape
# Out:
# (150, 5)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sepallength  150 non-null    float64
#  1   sepalwidth   150 non-null    float64
#  2   petallength  150 non-null    float64
#  3   petalwidth   150 non-null    float64
#  4   class        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
dataset=df.drop_duplicates(subset="class",)
dataset
# Out:
#      sepallength  sepalwidth  petallength  petalwidth            class
# 0            5.1         3.5          1.4         0.2      Iris-setosa
# 50           7.0         3.2          4.7         1.4  Iris-versicolor
# 100          6.3         3.3          6.0         2.5   Iris-virginica

# %%
df.value_counts()
# Out:
# sepallength  sepalwidth  petallength  petalwidth  class
# 5.1          3.5         1.4          0.2         Iris-setosa        1
# 6.3          3.3         6.0          2.5         Iris-virginica     1
# 7.0          3.2         4.7          1.4         Iris-versicolor    1
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(x='sepallength',y='sepalwidth' , data=dataset)
plt.show()

# %%
sns.countplot(x='class', data=dataset)
plt.show()

# %%
sns.scatterplot(x='sepallength', y='sepalwidth',
                hue='class', data=dataset, )

# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)

plt.show()


plt.hist(dataset['sepallength'], bins=7)
# Out:
# (array([1., 0., 0., 0., 1., 0., 1.]),
#  array([5.1       , 5.37142857, 5.64285714, 5.91428571, 6.18571429,
#         6.45714286, 6.72857143, 7.        ]),
#  <BarContainer object of 7 artists>)

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder,StandardScaler
from sklearn.model_selection import train_test_split

df = pd.read_csv('sample.csv')
df.head()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes

# %%
x=df.iloc[ :,:-1].values
y=df.iloc[ :,3:].values

imp= SimpleImputer(missing_values=np.nan ,strategy='mean')
x[:,1:3]=imp.fit_transform(x[:,1:3])


LE = LabelEncoder()
x[:,0]=LE.fit_transform(x[:,0])
y=LE.fit_transform(y)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
trans = ColumnTransformer([("norm1",OneHotEncoder(),[0])],remainder='passthrough')
trans.fit_transform(x)
# Out:
# array([[1.0, 0.0, 0.0, 44.0, 72000.0],
#        [0.0, 0.0, 1.0, 27.0, 48000.0],
#        [0.0, 1.0, 0.0, 30.0, 54000.0],
#        [0.0, 0.0, 1.0, 38.0, 61000.0],
#        [0.0, 1.0, 0.0, 40.0, 63777.77777777778],
#        [1.0, 0.0, 0.0, 35.0, 58000.0],
#        [0.0, 0.0, 1.0, 38.77777777777778, 52000.0],
#        [1.0, 0.0, 0.0, 48.0, 79000.0],
#        [0.0, 1.0, 0.0, 50.0, 83000.0],
#        [1.0, 0.0, 0.0, 37.0, 67000.0]], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
x_train
# Out:
# array([[1, 40.0, 63777.77777777778],
#        [0, 37.0, 67000.0],
#        [2, 27.0, 48000.0],
#        [2, 38.77777777777778, 52000.0],
#        [0, 48.0, 79000.0],
#        [2, 38.0, 61000.0],
#        [0, 44.0, 72000.0],
#        [0, 35.0, 58000.0]], dtype=object)

# %%
SC = StandardScaler()
x_train[3:5]=SC.fit_transform(x_train[3:5])
x_train
# Out:
# array([[1, 40.0, 63777.77777777778],
#        [0, 37.0, 67000.0],
#        [2, 27.0, 48000.0],
#        [1.0, -0.9999999999999992, -1.0],
#        [-1.0, 1.0000000000000007, 1.0],
#        [2, 38.0, 61000.0],
#        [0, 44.0, 72000.0],
#        [0, 35.0, 58000.0]], dtype=object)

# %%
df3=pd.read_csv('Clustering.csv')
df3
# Out:
#            Age  Annual_Income  Spending_Score
# 0    27.483571   69639.949392       69.376963
# 1    24.308678   75017.664489       84.735924
# 2    28.238443   71808.180125       70.805758
# 3    32.615149   66774.401227       95.499344
# 4    23.829233   71806.978028       72.167467
# ..         ...            ...             ...
# 193  54.823788   32852.993343       11.439162
# 194  57.231753   26183.704217       20.715662
# 195  54.010611   20975.589497       15.223426
# 196  69.823626   21862.287811       24.789798
# 197  60.176318   30240.424733       23.336621
#
# [198 rows x 3 columns]

# %%
df3=pd.read_csv('sample.csv')
df3
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df=pd.read_csv('linear.csv')
df
# Out:
#         X           y
# 0     1.0   12.467142
# 1     2.0    8.617357
# 2     3.0   18.976885
# 3     4.0   30.230299
# 4     5.0   15.158466
# ..    ...         ...
# 95   96.0  230.364851
# 96   97.0  250.461203
# 97   98.0  252.610553
# 98   99.0  252.551135
# 99  100.0  252.654129
#
# [100 rows x 2 columns]
